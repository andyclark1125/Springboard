# %% [markdown]
# # Capstone 2 Data Wrangling
# ### This objective of this notebook is to clean my data, address missing values and handle outliers.

# %%
# import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### The data is in a geologic csv.  The unique well id from geologic csv will be used to download well attribute data to generate the well data.  The geo and well data will then be combined into a single data frame.

# %% [markdown]
# ### This initial step is loading the geologic data and making it tidy.

# %%
# Load the data
geo_df = pd.read_csv('WFMP UA Value for Linear Regression Analysis.csv')

# %% [markdown]
# # Geologic data clean up:
# ### Data is not tidy, columns named ZoneAttrName and Value are rows that need to be cast to columns, but first remove unnecessary columns.

# %%
# View first few rows
geo_df.head()
# Out:
#               UWI            Well Name Well Number               Well Label  \
# 0  42109326190000  HORSESHOE SPRINGS S           1  HORSESHOE SPRINGS S : 1
# 1  42109326190000  HORSESHOE SPRINGS S           1  HORSESHOE SPRINGS S : 1
# 2  42109326190000  HORSESHOE SPRINGS S           1  HORSESHOE SPRINGS S : 1
# 3  42109326190000  HORSESHOE SPRINGS S           1  HORSESHOE SPRINGS S : 1
# 4  42109326190000  HORSESHOE SPRINGS S           1  HORSESHOE SPRINGS S : 1
#
#    KB Elev  DF Elev  GL Elev   Spud Date  Completion Date  Current Operator  \
# 0      NaN      NaN   3317.0  10/13/2013              NaN  BPX OPERATING CO
# 1      NaN      NaN   3317.0  10/13/2013              NaN  BPX OPERATING CO
# 2      NaN      NaN   3317.0  10/13/2013              NaN  BPX OPERATING CO
# 3      NaN      NaN   3317.0  10/13/2013              NaN  BPX OPERATING CO
# 4      NaN      NaN   3317.0  10/13/2013              NaN  BPX OPERATING CO
#
#    ...  Historical Operator     County  State    SurfLat    SurfLong  \
# 0  ...                  NaN  CULBERSON  TEXAS  31.744014 -104.142364
# 1  ...                  NaN  CULBERSON  TEXAS  31.744014 -104.142364
# 2  ...                  NaN  CULBERSON  TEXAS  31.744014 -104.142364
# 3  ...                  NaN  CULBERSON  TEXAS  31.744014 -104.142364
# 4  ...                  NaN  CULBERSON  TEXAS  31.744014 -104.142364
#
#     BHLatDec   BHLongDec     Zone Name  \
# 0  31.723918 -104.142354  Grid Samples
# 1  31.723918 -104.142354  Grid Samples
# 2  31.723918 -104.142354  Grid Samples
# 3  31.723918 -104.142354  Grid Samples
# 4  31.723918 -104.142354  Grid Samples
#
#                                         ZoneAttrName  Value
# 0                        VARIANCE_WFMP_UA_MRKR_SSTVD  10.51
# 1        VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100   0.02
# 2  VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity...  16.45
# 3                      VARIANCE_WFMP Upper A - GROSS   2.42
# 4                 VARIANCE_WFMP Upper A - NET_DPHI>8   0.05
#
# [5 rows x 21 columns]

# %%
# Remove unnecessary columns
geo_df.drop(labels=['Well Number', 'Well Label', 'KB Elev', 'DF Elev',
       'GL Elev','Original Operator','Historical Operator', 'County', 'State',
       'SurfLat', 'SurfLong','Zone Name','Completion Date'], axis=1, inplace=True)

# %%
geo_df.head()
# Out:
#               UWI            Well Name   Spud Date  Current Operator  \
# 0  42109326190000  HORSESHOE SPRINGS S  10/13/2013  BPX OPERATING CO
# 1  42109326190000  HORSESHOE SPRINGS S  10/13/2013  BPX OPERATING CO
# 2  42109326190000  HORSESHOE SPRINGS S  10/13/2013  BPX OPERATING CO
# 3  42109326190000  HORSESHOE SPRINGS S  10/13/2013  BPX OPERATING CO
# 4  42109326190000  HORSESHOE SPRINGS S  10/13/2013  BPX OPERATING CO
#
#     BHLatDec   BHLongDec                                       ZoneAttrName  \
# 0  31.723918 -104.142354                        VARIANCE_WFMP_UA_MRKR_SSTVD
# 1  31.723918 -104.142354        VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100
# 2  31.723918 -104.142354  VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity...
# 3  31.723918 -104.142354                      VARIANCE_WFMP Upper A - GROSS
# 4  31.723918 -104.142354                 VARIANCE_WFMP Upper A - NET_DPHI>8
#
#    Value
# 0  10.51
# 1   0.02
# 2  16.45
# 3   2.42
# 4   0.05

# %%
# Pivot the df to cast the ZoneAttrName to columns
geo_df_wide = geo_df.pivot(index='UWI', columns='ZoneAttrName',values='Value').copy()
geo_df_wide.head()
# Out:
# ZoneAttrName    MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100  \
# UWI
# 42109326190000                                       5.82
# 42109326530000                                       7.77
# 42109326540000                                       9.32
# 42109328220000                                       8.08
# 42109328300000                                       7.27
#
# ZoneAttrName    MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  \
# UWI
# 42109326190000                                            115.92
# 42109326530000                                             63.18
# 42109326540000                                             48.76
# 42109328220000                                            145.63
# 42109328300000                                             86.09
#
# ZoneAttrName    MEDIAN_WFMP Upper A - GROSS  MEDIAN_WFMP Upper A - NET_DPHI>8  \
# UWI
# 42109326190000                       105.07                             53.72
# 42109326530000                        84.56                             52.09
# 42109326540000                       141.75                             94.76
# 42109328220000                       129.67                             78.99
# 42109328300000                        99.33                             58.19
#
# ZoneAttrName    MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8  \
# UWI
# 42109326190000                                     NaN
# 42109326530000                                     NaN
# 42109326540000                                   86.25
# 42109328220000                                   59.00
# 42109328300000                                     NaN
#
# ZoneAttrName    MEDIAN_WFMP Upper A - NET_Res>30  MEDIAN_WFMP_UA_MRKR_SSTVD  \
# UWI
# 42109326190000                             95.25                   -5566.93
# 42109326530000                             67.85                   -5467.08
# 42109326540000                            100.22                   -6154.35
# 42109328220000                            130.17                   -6014.65
# 42109328300000                             86.12                   -5621.27
#
# ZoneAttrName    VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100  \
# UWI
# 42109326190000                                         0.02
# 42109326530000                                         0.05
# 42109326540000                                         0.01
# 42109328220000                                         0.01
# 42109328300000                                         0.04
#
# ZoneAttrName    VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  \
# UWI
# 42109326190000                                              16.45
# 42109326530000                                              15.29
# 42109326540000                                               0.10
# 42109328220000                                              40.64
# 42109328300000                                              29.41
#
# ZoneAttrName    VARIANCE_WFMP Upper A - GROSS  \
# UWI
# 42109326190000                           2.42
# 42109326530000                           0.09
# 42109326540000                           2.83
# 42109328220000                           7.21
# 42109328300000                           1.59
#
# ZoneAttrName    VARIANCE_WFMP Upper A - NET_DPHI>8  \
# UWI
# 42109326190000                                0.05
# 42109326530000                                0.86
# 42109326540000                                2.91
# 42109328220000                                3.41
# 42109328300000                                0.07
#
# ZoneAttrName    VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8  \
# UWI
# 42109326190000                                       NaN
# 42109326530000                                       NaN
# 42109326540000                                      1.37
# 42109328220000                                      0.00
# 42109328300000                                       NaN
#
# ZoneAttrName    VARIANCE_WFMP Upper A - NET_Res>30  \
# UWI
# 42109326190000                                2.80
# 42109326530000                                2.03
# 42109326540000                               13.71
# 42109328220000                               13.59
# 42109328300000                                4.92
#
# ZoneAttrName    VARIANCE_WFMP_UA_MRKR_SSTVD
# UWI
# 42109326190000                        10.51
# 42109326530000                        64.85
# 42109326540000                        17.92
# 42109328220000                      1308.80
# 42109328300000                        48.23

# %%
# Explore the geo data, NaN
geo_df_wide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 42109326190000 to 42475381870000
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100           996 non-null    float64
#  1   MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS    993 non-null    float64
#  2   MEDIAN_WFMP Upper A - GROSS                         997 non-null    float64
#  3   MEDIAN_WFMP Upper A - NET_DPHI>8                    996 non-null    float64
#  4   MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8              859 non-null    float64
#  5   MEDIAN_WFMP Upper A - NET_Res>30                    993 non-null    float64
#  6   MEDIAN_WFMP_UA_MRKR_SSTVD                           997 non-null    float64
#  7   VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100         996 non-null    float64
#  8   VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  993 non-null    float64
#  9   VARIANCE_WFMP Upper A - GROSS                       997 non-null    float64
#  10  VARIANCE_WFMP Upper A - NET_DPHI>8                  996 non-null    float64
#  11  VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8            859 non-null    float64
#  12  VARIANCE_WFMP Upper A - NET_Res>30                  993 non-null    float64
#  13  VARIANCE_WFMP_UA_MRKR_SSTVD                         997 non-null    float64
# dtypes: float64(14)
# memory usage: 116.8 KB

# %% [markdown]
# ### There is some NAN in the geo data, due to not all wells have that data available.  I talked with the geologist and we agreed to proceed with the analysis with the NaN values.
# # Get the UWI for the wells and download the data from external source.

# %%
# UWI list to get the 12 month cum oil data as well as well attributes, 
# use the UWI from csv below to load into external database for public well data
geo_df_wide.to_csv('UWI.csv')

# %%
# Load in the well data from external source
well_df = pd.read_csv('well_data.csv')

# %%
# Take a look at how many nulls and data types
well_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unformatted_API_UWI_14               1072 non-null   int64
#  1   ENVOperator                          1072 non-null   object
#  2   FirstProdDate                        1053 non-null   object
#  3   LateralLength_FT                     1000 non-null   float64
#  4   ProppantIntensity_LBSPerFT           866 non-null    float64
#  5   WaterIntensity_GALPerFT              916 non-null    float64
#  6   OilGravity_API                       951 non-null    float64
#  7   AvgHzDistAtDrillTimeSameZone_FT      572 non-null    float64
#  8   ClosestHzDistAtDrillTimeSameZone_FT  572 non-null    float64
#  9   WellName                             1072 non-null   object
#  10  First12MonthOil_BBL                  917 non-null    float64
#  11  First12MonthGas_MCF                  917 non-null    float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 100.6+ KB

# %%
well_df.head()
# Out:
#    Unformatted_API_UWI_14  ENVOperator FirstProdDate  LateralLength_FT  \
# 0          42109328220000   PDC ENERGY      7/1/2015          7411.000
# 1          42389366240000      CHEVRON     12/1/2019         10370.021
# 2          42389367080000          EOG      8/1/2018          7471.000
# 3          42389368300000      CHEVRON     12/1/2018          9799.000
# 4          42389369700000  DIAMONDBACK     11/1/2018          6300.000
#
#    ProppantIntensity_LBSPerFT  WaterIntensity_GALPerFT  OilGravity_API  \
# 0                   1237.0258                1148.2241            51.0
# 1                         NaN                      NaN             NaN
# 2                   2442.3772                1962.7172            48.0
# 3                   2548.8423                2015.3563            43.0
# 4                   2027.8954                2292.8132            47.0
#
#    AvgHzDistAtDrillTimeSameZone_FT  ClosestHzDistAtDrillTimeSameZone_FT  \
# 0                              NaN                                  NaN
# 1                      1261.262458                           763.056321
# 2                       752.442952                           752.442952
# 3                      1182.870377                          1006.295644
# 4                       879.593524                           879.593524
#
#                                 WellName  First12MonthOil_BBL  \
# 0                  STATE SRO 45-18X19 1H            35960.000
# 1                MONROE 28-39 UNIT C 10H            18669.018
# 2               STATE CREEK 17-8 UNIT 7H           260675.000
# 3      RAGAN SMITH STATE 36-37 UNIT A 7H           205080.000
# 4  MISBEHAVING STATE UNIT C19-19-14 606H           108171.070
#
#    First12MonthGas_MCF
# 0           132399.000
# 1            47059.465
# 2          1183330.000
# 3           453275.220
# 4           294123.120

# %%
# After talking to the data provider, NaN for the distance attributes should be set to 2600'
well_df[['AvgHzDistAtDrillTimeSameZone_FT', 'ClosestHzDistAtDrillTimeSameZone_FT']] = well_df[['AvgHzDistAtDrillTimeSameZone_FT', 'ClosestHzDistAtDrillTimeSameZone_FT']].fillna(value=2600)

# %% [markdown]
# # Combine geo_df_wide with well_df on API

# %%
# make a consistent column name to match rows
old_names = ['Unformatted_API_UWI_14']
new_names = ['API']
well_df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
well_df.columns
# Out:
# Index(['API', 'ENVOperator', 'FirstProdDate', 'LateralLength_FT',
#        'ProppantIntensity_LBSPerFT', 'WaterIntensity_GALPerFT',
#        'OilGravity_API', 'AvgHzDistAtDrillTimeSameZone_FT',
#        'ClosestHzDistAtDrillTimeSameZone_FT', 'WellName',
#        'First12MonthOil_BBL', 'First12MonthGas_MCF'],
#       dtype='object')

# %%
# make a consistent column name to match rows
geo_df_wide.reset_index(inplace=True)
geo_df_wide.columns
# Out:
# Index(['UWI', 'MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'MEDIAN_WFMP Upper A - GROSS', 'MEDIAN_WFMP Upper A - NET_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_Res>30', 'MEDIAN_WFMP_UA_MRKR_SSTVD',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'VARIANCE_WFMP Upper A - GROSS', 'VARIANCE_WFMP Upper A - NET_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_Res>30', 'VARIANCE_WFMP_UA_MRKR_SSTVD'],
#       dtype='object', name='ZoneAttrName')

# %%
# make a consistent column name to match rows
old_names = ['UWI']
new_names = ['API']
geo_df_wide.rename(columns=dict(zip(old_names, new_names)), inplace=True)
geo_df_wide.columns
# Out:
# Index(['API', 'MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'MEDIAN_WFMP Upper A - GROSS', 'MEDIAN_WFMP Upper A - NET_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_Res>30', 'MEDIAN_WFMP_UA_MRKR_SSTVD',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'VARIANCE_WFMP Upper A - GROSS', 'VARIANCE_WFMP Upper A - NET_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_Res>30', 'VARIANCE_WFMP_UA_MRKR_SSTVD'],
#       dtype='object', name='ZoneAttrName')

# %%
# convert from API unique indentifier from number to string
well_df.API = well_df.API.astype('str')
geo_df_wide.API = geo_df_wide.API.astype('str')

# %%
#df_merged = pd.merge(well_df, geo_df_wide, on=["API","API"])
df_merged = pd.merge(well_df, geo_df_wide, on=["API"])

# %%
df_merged.shape
# Out:
# (944, 26)

# %%
df_merged.describe()
# Out:
#        LateralLength_FT  ProppantIntensity_LBSPerFT  WaterIntensity_GALPerFT  \
# count        918.000000                  808.000000               858.000000
# mean        7258.974923                 2153.043914              2107.263977
# std         2389.399966                  595.413275               667.209581
# min          821.000000                    0.183055                23.309273
# 25%         4764.000000                 1823.165675              1744.697575
# 50%         7320.000000                 2286.283600              2115.365600
# 75%         9592.750000                 2510.029400              2436.680975
# max        20053.000000                 5043.544000              7635.866000
#
#        OilGravity_API  AvgHzDistAtDrillTimeSameZone_FT  \
# count      890.000000                       944.000000
# mean        47.171910                      1733.930090
# std          4.594306                       820.374141
# min         10.000000                       190.693018
# 25%         44.000000                       883.187425
# 50%         47.000000                      1625.905176
# 75%         49.000000                      2600.000000
# max         70.000000                      2636.737658
#
#        ClosestHzDistAtDrillTimeSameZone_FT  First12MonthOil_BBL  \
# count                           944.000000           862.000000
# mean                           1688.788646        156238.185205
# std                             854.151386         76923.461138
# min                             190.693018          1627.000000
# 25%                             837.991909        100260.520000
# 50%                            1533.808920        145517.000000
# 75%                            2600.000000        201230.982500
# max                            2636.737658        432672.000000
#
#        First12MonthGas_MCF  MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100  \
# count         8.620000e+02                                 943.000000
# mean          6.224645e+05                                   9.591315
# std           4.114028e+05                                   2.896924
# min           2.400000e+01                                 -30.340000
# 25%           3.345412e+05                                   9.190000
# 50%           5.145880e+05                                   9.960000
# 75%           8.311485e+05                                  10.710000
# max           3.270669e+06                                  14.440000
#
#        MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  ...  \
# count                                        941.000000  ...
# mean                                         100.765685  ...
# std                                           34.961520  ...
# min                                           12.970000  ...
# 25%                                           78.200000  ...
# 50%                                           94.520000  ...
# 75%                                          116.260000  ...
# max                                          251.480000  ...
#
#        MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8  \
# count                              813.000000
# mean                                71.073100
# std                                 16.782296
# min                                 10.070000
# 25%                                 60.940000
# 50%                                 70.180000
# 75%                                 82.730000
# max                                110.960000
#
#        MEDIAN_WFMP Upper A - NET_Res>30  MEDIAN_WFMP_UA_MRKR_SSTVD  \
# count                        941.000000                 944.000000
# mean                          95.057747               -7490.593983
# std                           21.057502                 658.329444
# min                            7.110000               -8456.910000
# 25%                           80.750000               -7955.502500
# 50%                           90.480000               -7637.330000
# 75%                          109.290000               -7235.947500
# max                          145.260000               -3749.360000
#
#        VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100  \
# count                                   943.000000
# mean                                      0.569533
# std                                       7.428175
# min                                       0.000000
# 25%                                       0.010000
# 50%                                       0.020000
# 75%                                       0.080000
# max                                     212.150000
#
#        VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  \
# count                                         941.000000
# mean                                           34.191137
# std                                            90.464180
# min                                             0.000000
# 25%                                             1.350000
# 50%                                             6.920000
# 75%                                            27.060000
# max                                          1532.790000
#
#        VARIANCE_WFMP Upper A - GROSS  VARIANCE_WFMP Upper A - NET_DPHI>8  \
# count                     944.000000                          943.000000
# mean                        6.011155                            6.896607
# std                        11.276048                           18.206390
# min                         0.000000                            0.000000
# 25%                         0.467500                            0.435000
# 50%                         1.960000                            1.640000
# 75%                         6.037500                            5.945000
# max                       110.260000                          294.150000
#
#        VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8  \
# count                                813.000000
# mean                                   4.126052
# std                                   10.133303
# min                                    0.000000
# 25%                                    0.250000
# 50%                                    0.940000
# 75%                                    2.850000
# max                                  131.030000
#
#        VARIANCE_WFMP Upper A - NET_Res>30  VARIANCE_WFMP_UA_MRKR_SSTVD
# count                          941.000000                   944.000000
# mean                             5.658045                   643.133528
# std                             15.677595                  1366.129622
# min                              0.000000                     0.030000
# 25%                              0.400000                    40.667500
# 50%                              1.550000                   181.280000
# 75%                              4.620000                   520.532500
# max                            242.160000                 12541.330000
#
# [8 rows x 22 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 944 entries, 0 to 943
# Data columns (total 26 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   API                                                 944 non-null    object
#  1   ENVOperator                                         944 non-null    object
#  2   FirstProdDate                                       926 non-null    object
#  3   LateralLength_FT                                    918 non-null    float64
#  4   ProppantIntensity_LBSPerFT                          808 non-null    float64
#  5   WaterIntensity_GALPerFT                             858 non-null    float64
#  6   OilGravity_API                                      890 non-null    float64
#  7   AvgHzDistAtDrillTimeSameZone_FT                     944 non-null    float64
#  8   ClosestHzDistAtDrillTimeSameZone_FT                 944 non-null    float64
#  9   WellName                                            944 non-null    object
#  10  First12MonthOil_BBL                                 862 non-null    float64
#  11  First12MonthGas_MCF                                 862 non-null    float64
#  12  MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100           943 non-null    float64
#  13  MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS    941 non-null    float64
#  14  MEDIAN_WFMP Upper A - GROSS                         944 non-null    float64
#  15  MEDIAN_WFMP Upper A - NET_DPHI>8                    943 non-null    float64
#  16  MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8              813 non-null    float64
#  17  MEDIAN_WFMP Upper A - NET_Res>30                    941 non-null    float64
#  18  MEDIAN_WFMP_UA_MRKR_SSTVD                           944 non-null    float64
#  19  VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100         943 non-null    float64
#  20  VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  941 non-null    float64
#  21  VARIANCE_WFMP Upper A - GROSS                       944 non-null    float64
#  22  VARIANCE_WFMP Upper A - NET_DPHI>8                  943 non-null    float64
#  23  VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8            813 non-null    float64
#  24  VARIANCE_WFMP Upper A - NET_Res>30                  941 non-null    float64
#  25  VARIANCE_WFMP_UA_MRKR_SSTVD                         944 non-null    float64
# dtypes: float64(22), object(4)
# memory usage: 199.1+ KB

# %%
# remove unnecessary columns
df_merged.drop(columns=['WellName'], inplace=True)

# %% [markdown]
# # Dataset has been cleaned up, perform EDA

# %% [markdown]
# ### Data appears log-normally distributed with no apparent outliers

# %%
#Create a histogram of 12 Month Cum Oil
plt.hist(df_merged['First12MonthOil_BBL'], bins=40)
plt.ylabel('count')
plt.xlabel('12 Month Cum Oil (bbls)')
plt.axvline(df_merged['First12MonthOil_BBL'].mean(), color='red', linestyle='--', linewidth=3, label='mean')
plt.axvline(df_merged['First12MonthOil_BBL'].median(), color='blue', linestyle='solid', linewidth=3, label='median')
plt.legend()
plt.show()

# %%
# select numeric columns only and get column names to arrange columns with 12 Month Cum Oil first
df_num = df_merged.select_dtypes(include=['float64'])
names = df_num.columns
names
# Out:
# Index(['LateralLength_FT', 'ProppantIntensity_LBSPerFT',
#        'WaterIntensity_GALPerFT', 'OilGravity_API',
#        'AvgHzDistAtDrillTimeSameZone_FT',
#        'ClosestHzDistAtDrillTimeSameZone_FT', 'First12MonthOil_BBL',
#        'First12MonthGas_MCF', 'MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'MEDIAN_WFMP Upper A - GROSS', 'MEDIAN_WFMP Upper A - NET_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_Res>30', 'MEDIAN_WFMP_UA_MRKR_SSTVD',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'VARIANCE_WFMP Upper A - GROSS', 'VARIANCE_WFMP Upper A - NET_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_Res>30', 'VARIANCE_WFMP_UA_MRKR_SSTVD'],
#       dtype='object')

# %%
# Create a GOR attribute, more gassy wells might correlate to lower oil cum
#df_num['gor scf/stb'] = df_num['First12MonthGas_MCF']/df_num['First12MonthOil_BBL']
gor = df_num['First12MonthGas_MCF']/df_num['First12MonthOil_BBL']*1000
df_num.loc[:, 'gor scf/stb'] = gor
# Out:
# C:\Users\asclark\Anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\asclark\Anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
df_num.head()
# Out:
#    LateralLength_FT  ProppantIntensity_LBSPerFT  WaterIntensity_GALPerFT  \
# 0          7411.000                   1237.0258                1148.2241
# 1         10370.021                         NaN                      NaN
# 2          7471.000                   2442.3772                1962.7172
# 3          9799.000                   2548.8423                2015.3563
# 4          6300.000                   2027.8954                2292.8132
#
#    OilGravity_API  AvgHzDistAtDrillTimeSameZone_FT  \
# 0            51.0                      2600.000000
# 1             NaN                      1261.262458
# 2            48.0                       752.442952
# 3            43.0                      1182.870377
# 4            47.0                       879.593524
#
#    ClosestHzDistAtDrillTimeSameZone_FT  First12MonthOil_BBL  \
# 0                          2600.000000            35960.000
# 1                           763.056321            18669.018
# 2                           752.442952           260675.000
# 3                          1006.295644           205080.000
# 4                           879.593524           108171.070
#
#    First12MonthGas_MCF  MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100  \
# 0           132399.000                                       8.08
# 1            47059.465                                       9.94
# 2          1183330.000                                       9.47
# 3           453275.220                                      10.29
# 4           294123.120                                      11.19
#
#    MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  ...  \
# 0                                            145.63  ...
# 1                                            110.30  ...
# 2                                             81.96  ...
# 3                                            107.95  ...
# 4                                             52.49  ...
#
#    MEDIAN_WFMP Upper A - NET_Res>30  MEDIAN_WFMP_UA_MRKR_SSTVD  \
# 0                            130.17                   -6014.65
# 1                             90.29                   -7886.27
# 2                             99.81                   -7139.56
# 3                             85.47                   -8000.61
# 4                             90.69                   -8114.49
#
#    VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100  \
# 0                                         0.01
# 1                                         0.01
# 2                                         0.02
# 3                                         0.07
# 4                                         0.01
#
#    VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS  \
# 0                                              40.64
# 1                                              12.44
# 2                                               6.64
# 3                                              37.53
# 4                                               0.61
#
#    VARIANCE_WFMP Upper A - GROSS  VARIANCE_WFMP Upper A - NET_DPHI>8  \
# 0                           7.21                                3.41
# 1                           0.24                                1.56
# 2                           4.33                                0.75
# 3                           5.03                                6.17
# 4                           2.12                                0.19
#
#    VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8  \
# 0                                      0.00
# 1                                      2.15
# 2                                      0.10
# 3                                      1.39
# 4                                      0.46
#
#    VARIANCE_WFMP Upper A - NET_Res>30  VARIANCE_WFMP_UA_MRKR_SSTVD  \
# 0                               13.59                      1308.80
# 1                                1.60                       302.59
# 2                                3.27                         7.04
# 3                                2.61                       478.22
# 4                                0.34                      5179.07
#
#    gor scf/stb
# 0  3681.840934
# 1  2520.725247
# 2  4539.484032
# 3  2210.236103
# 4  2719.055289
#
# [5 rows x 23 columns]

# %%
names = ['First12MonthOil_BBL', 'LateralLength_FT', 'ProppantIntensity_LBSPerFT',
       'WaterIntensity_GALPerFT', 'OilGravity_API',
       'AvgHzDistAtDrillTimeSameZone_FT',
       'ClosestHzDistAtDrillTimeSameZone_FT', 'MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100',
       'MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
       'MEDIAN_WFMP Upper A - GROSS', 'MEDIAN_WFMP Upper A - NET_DPHI>8',
       'MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8',
       'MEDIAN_WFMP Upper A - NET_Res>30', 'MEDIAN_WFMP_UA_MRKR_SSTVD',
       'VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100',
       'VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
       'VARIANCE_WFMP Upper A - GROSS', 'VARIANCE_WFMP Upper A - NET_DPHI>8',
       'VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8',
       'VARIANCE_WFMP Upper A - NET_Res>30', 'VARIANCE_WFMP_UA_MRKR_SSTVD','gor scf/stb']
df_num = df_num[names]
df_num.columns
# Out:
# Index(['First12MonthOil_BBL', 'LateralLength_FT', 'ProppantIntensity_LBSPerFT',
#        'WaterIntensity_GALPerFT', 'OilGravity_API',
#        'AvgHzDistAtDrillTimeSameZone_FT',
#        'ClosestHzDistAtDrillTimeSameZone_FT',
#        'MEDIAN_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'MEDIAN_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'MEDIAN_WFMP Upper A - GROSS', 'MEDIAN_WFMP Upper A - NET_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_GR>75_DPHI>8',
#        'MEDIAN_WFMP Upper A - NET_Res>30', 'MEDIAN_WFMP_UA_MRKR_SSTVD',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_DPHI_100',
#        'VARIANCE_WFMP Upper A - ARITH_MEAN_Resistivity_ALS',
#        'VARIANCE_WFMP Upper A - GROSS', 'VARIANCE_WFMP Upper A - NET_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_GR>75_DPHI>8',
#        'VARIANCE_WFMP Upper A - NET_Res>30', 'VARIANCE_WFMP_UA_MRKR_SSTVD',
#        'gor scf/stb'],
#       dtype='object')

# %%
# Write out the cleaned data so that it can be read in for Preprocessing capstone
df_num.to_csv('df_num.csv')
